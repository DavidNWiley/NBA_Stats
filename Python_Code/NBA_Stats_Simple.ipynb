# %%
from bs4 import BeautifulSoup
import requests as rq
from datetime import datetime
import pandas as pd
import numpy as np
import re

# %%
url = 'https://www.basketball-reference.com/teams/HOU/2020.html'

agent = {'User-Agent': 'Mozilla/5.0'}

url_text = rq.get(url, headers=agent).text

soup = BeautifulSoup(url_text, 'html.parser')

# %%
##################################################################################
# Roster Table
##################################################################################

roster_df = pd.DataFrame()

roster_table = soup.find('table', attrs={'id': 'roster'})

roster_info = roster_table.find('tbody')

for tr in roster_info.find_all('tr'):

        nmbr = tr.find('th')

        roster_dict = {}
        
        if nmbr['data-stat'] == 'number':
            
            roster_dict[nmbr['data-stat']] = nmbr.text

        
        for td in tr.find_all('td'):
            
            if td['data-stat'] == 'player':
                roster_dict['link'] = td.contents[0]['href'] 
            
            roster_dict[td['data-stat']] = td.text

        roster_df = roster_df.append(roster_dict, ignore_index=True)

roster_df.head()
# Out:
#   birth_country         birth_date        college height  \
# 0            us        May 5, 1985          Texas    6-5
# 1            us  February 11, 1993         Kansas    6-3
# 2            us    August 26, 1989  Arizona State    6-5
# 3            us     August 1, 1992           Duke    6-3
# 4            us       June 7, 1993      Texas A&M    6-6
#
#                         link number         player pos weight years_experience
# 0  /players/t/tuckepj01.html     17    P.J. Tucker  PF    245                8
# 1  /players/m/mclembe01.html     16   Ben McLemore  SG    195                6
# 2  /players/h/hardeja01.html     13   James Harden  SG    220               10
# 3  /players/r/riverau01.html     25  Austin Rivers  SG    200                7
# 4  /players/h/houseda01.html      4   Danuel House  SF    215                3

# %%
##################################################################################
# Per Game Table
##################################################################################
pg_df = pd.DataFrame()

pg_table = soup.find('div', attrs={'id': 'all_per_game'})

pg_info = BeautifulSoup(pg_table.contents[5], 'lxml')

pg_data = pg_info.find('tbody')

for tr in pg_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    pg_dict = {}
    
    pg_dict['rank'] = rnk.text
     

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            pg_dict['link'] = td.contents[0]['href']  
        
        pg_dict[td['data-stat']] = td.text

    pg_df = pg_df.append(pg_dict, ignore_index=True)

pg_df.head()
# Out:
#   age ast_per_g blk_per_g drb_per_g efg_pct fg2_pct fg2_per_g fg2a_per_g  \
# 0  30       7.5       0.9       5.5    .543    .556       5.5        9.9
# 1  31       7.0       0.4       6.2    .493    .514       9.6       18.7
# 2  34       1.6       0.5       5.1    .541    .551       1.0        1.8
# 3  29       1.5       2.2       6.8    .509    .610       1.6        2.7
# 4  25       1.2       1.8       9.5    .629    .629       6.3        9.9
#
#   fg3_pct fg3_per_g  ...                       link mp_per_g orb_per_g  \
# 0    .355       4.4  ...  /players/h/hardeja01.html     36.5       1.0
# 1    .258       1.0  ...  /players/w/westbru01.html     35.9       1.8
# 2    .358       1.5  ...  /players/t/tuckepj01.html     34.3       1.6
# 3    .315       2.4  ...  /players/c/covinro01.html     33.0       1.2
# 4               0.0  ...  /players/c/capelca01.html     32.8       4.3
#
#   pf_per_g             player pts_per_g rank stl_per_g tov_per_g trb_per_g
# 0      3.3       James Harden      34.3    1       1.8       4.5       6.6
# 1      3.5  Russell Westbrook      27.2    2       1.6       4.5       7.9
# 2      3.2        P.J. Tucker       6.9    3       1.1       1.0       6.6
# 3      3.3   Robert Covington      11.6    4       1.6       1.4       8.0
# 4      2.6       Clint Capela      13.9    5       0.8       1.6      13.8
#
# [5 rows x 29 columns]

# %%
##################################################################################
# All Totals Table
##################################################################################

at_df = pd.DataFrame()

at_table = soup.find('div', attrs={'id': 'all_totals'})

at_info = BeautifulSoup(at_table.contents[5], 'lxml')

at_data = at_info.find('tbody')

for tr in at_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    at_dict = {}
    
    at_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            at_dict['link'] = td.contents[0]['href'] 
            
        at_dict[td['data-stat']] = td.text

    at_df = at_df.append(at_dict, ignore_index=True)

at_df.head()
# Out:
#   age  ast blk  drb efg_pct   fg  fg2 fg2_pct  fg2a  fg3  ...  \
# 0  30  512  60  376    .543  672  373    .556   671  299  ...
# 1  34  115  36  364    .541  177   70    .551   127  107  ...
# 2  31  401  20  351    .493  604  549    .514  1068   55  ...
# 3  26   85  34  210    .546  230  101    .549   184  129  ...
# 4  26   58  16  136    .610  242   61    .656    93  181  ...
#
#                         link    mp  orb   pf             player   pts rank  \
# 0  /players/h/hardeja01.html  2483   70  227       James Harden  2335    1
# 1  /players/t/tuckepj01.html  2467  112  229        P.J. Tucker   500    2
# 2  /players/w/westbru01.html  2049  100  200  Russell Westbrook  1553    3
# 3  /players/h/houseda01.html  1913   57  132       Danuel House   662    4
# 4  /players/m/mclembe01.html  1619   21  155       Ben McLemore   715    5
#
#    stl  tov  trb
# 0  125  308  446
# 1   77   72  476
# 2   93  255  451
# 3   67   54  267
# 4   45   50  157
#
# [5 rows x 29 columns]

# %%
##################################################################################
# Per 36 Minutes Table
##################################################################################

per_mp_df = pd.DataFrame()

per_mp_table = soup.find('div', attrs={'id': 'all_per_minute'})

per_mp_info = BeautifulSoup(per_mp_table.contents[5], 'lxml')

per_mp_data = per_mp_info.find('tbody')

for tr in per_mp_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    per_mp_dict = {}
    
    per_mp_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            per_mp_dict['link'] = td.contents[0]['href'] 

        per_mp_dict[td['data-stat']] = td.text

    per_mp_df = per_mp_df.append(per_mp_dict, ignore_index=True)

per_mp_df.head()
# Out:
#   age ast_per_mp blk_per_mp drb_per_mp fg2_pct fg2_per_mp fg2a_per_mp fg3_pct  \
# 0  30        7.4        0.9        5.5    .556        5.4         9.7    .355
# 1  34        1.7        0.5        5.3    .551        1.0         1.9    .358
# 2  31        7.0        0.4        6.2    .514        9.6        18.8    .258
# 3  26        1.6        0.6        4.0    .549        1.9         3.5    .363
# 4  26        1.3        0.4        3.0    .656        1.4         2.1    .400
#
#   fg3_per_mp fg3a_per_mp  ...                       link    mp orb_per_mp  \
# 0        4.3        12.2  ...  /players/h/hardeja01.html  2483        1.0
# 1        1.6         4.4  ...  /players/t/tuckepj01.html  2467        1.6
# 2        1.0         3.7  ...  /players/w/westbru01.html  2049        1.8
# 3        2.4         6.7  ...  /players/h/houseda01.html  1913        1.1
# 4        4.0        10.1  ...  /players/m/mclembe01.html  1619        0.5
#
#   pf_per_mp             player pts_per_mp rank stl_per_mp tov_per_mp  \
# 0       3.3       James Harden       33.9    1        1.8        4.5
# 1       3.3        P.J. Tucker        7.3    2        1.1        1.1
# 2       3.5  Russell Westbrook       27.3    3        1.6        4.5
# 3       2.5       Danuel House       12.5    4        1.3        1.0
# 4       3.4       Ben McLemore       15.9    5        1.0        1.1
#
#   trb_per_mp
# 0        6.5
# 1        6.9
# 2        7.9
# 3        5.0
# 4        3.5
#
# [5 rows x 28 columns]

# %%
##################################################################################################
# Per 100 Poss Table
##################################################################################################

per_poss_df = pd.DataFrame()

per_poss_table = soup.find('div', attrs={'id': 'all_per_poss'})

per_poss_info = BeautifulSoup(per_poss_table.contents[5], 'lxml')

per_poss_data = per_poss_info.find('tbody')

for tr in per_poss_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    per_poss_dict = {}
    
    per_poss_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            per_poss_dict['link'] = td.contents[0]['href'] 
        
        per_poss_dict[td['data-stat']] = td.text

    per_poss_df = per_poss_df.append(per_poss_dict, ignore_index=True)

per_poss_df.head()
# Out:
#     age ast_per_poss blk_per_poss def_rtg drb_per_poss fg2_pct fg2_per_poss  \
# 0    30          9.5          1.1     108          7.0    .556          7.0
# 1    34          2.2          0.7     111          6.8    .551          1.3
# 2    31          9.1          0.5     109          7.9    .514         12.4
# 3    26          2.1          0.8     112          5.1    .549          2.4
# 4    26          1.7          0.5     113          3.9    .656          1.7
#
#   fg2a_per_poss fg3_pct  ...    mp off_rtg orb_per_poss pf_per_poss  \
# 0          12.5    .355  ...  2483     120          1.3         4.2
# 1           2.4    .358  ...  2467     114          2.1         4.3
# 2          24.1    .258  ...  2049     106          2.3         4.5
# 3           4.5    .363  ...  1913     114          1.4         3.2
# 4           2.7    .400  ...  1619     118          0.6         4.4
#
#               player pts_per_poss rank stl_per_poss tov_per_poss trb_per_poss
# 0       James Harden         43.5    1          2.3          5.7          8.3
# 1        P.J. Tucker          9.4    2          1.4          1.4          8.9
# 2  Russell Westbrook         35.1    3          2.1          5.8         10.2
# 3       Danuel House         16.0    4          1.6          1.3          6.5
# 4       Ben McLemore         20.4    5          1.3          1.4          4.5
#
# [5 rows x 31 columns]

# %%
##################################################################################################
# Advanced Table
##################################################################################################

adv_df = pd.DataFrame()

adv_table = soup.find('div', attrs={'id': 'all_advanced'})

adv_info = BeautifulSoup(adv_table.contents[5], 'lxml')

adv_data = adv_info.find('tbody')

for tr in adv_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    adv_dict = {}
    
    adv_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            adv_dict['link'] = td.contents[0]['href'] 
        
        adv_dict[td['data-stat']] = td.text

    adv_df = adv_df.append(adv_dict, ignore_index=True)

adv_df.head()
# Out:
#   age ast_pct blk_pct   bpm bpm-dum  dbpm drb_pct  dws fg3a_per_fga_pct  \
# 0  30    35.9     2.1   9.7           1.5    16.0  3.2             .557
# 1  34     6.0     1.2  -1.8           0.5    15.6  2.4             .702
# 2  31    35.6     0.8   1.5          -0.2    18.1  2.5             .166
# 3  26     6.1     1.5  -0.6           0.0    11.6  1.8             .659
# 4  26     5.2     0.8  -0.5          -0.6     8.9  1.1             .829
#
#   fta_per_fga_pct  ... rank stl_pct tov_pct trb_pct ts_pct usg_pct vorp    ws  \
# 0            .528  ...    1     2.3    14.2     9.4   .626    36.3  7.3  13.1
# 1            .113  ...    2     1.4    13.9    10.1   .559     8.7  0.1   4.0
# 2            .297  ...    3     2.1    15.0    11.5   .536    34.4  1.8   4.2
# 3            .167  ...    4     1.6     8.5     7.3   .572    13.7  0.7   3.6
# 4            .123  ...    5     1.3     8.0     5.1   .622    16.0  0.6   3.3
#
#   ws-dum ws_per_48
# 0             .254
# 1             .078
# 2             .098
# 3             .091
# 4             .099
#
# [5 rows x 28 columns]

# %%
##################################################################################################
# Adjusted Shooting Table
##################################################################################################

adj_shooting_df = pd.DataFrame()

adj_shooting_table = soup.find('div', attrs={'id': 'all_adj-shooting'})

adj_shooting_info = BeautifulSoup(adj_shooting_table.contents[5], 'lxml')

adj_shooting_data = adj_shooting_info.find('tbody')

for tr in adj_shooting_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    adj_shooting_dict = {}
    
    adj_shooting_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            adj_shooting_dict['link'] = td.contents[0]['href'] 
        
        adj_shooting_dict[td['data-stat']] = td.text

    adj_shooting_df = adj_shooting_df.append(adj_shooting_dict, ignore_index=True)

names = adj_shooting_df.columns

for n in names:
    dummy = re.match('DUMMY[\d]?[\s]?', n)
    if dummy:
        adj_shooting_df = adj_shooting_df.drop(dummy.group(), axis=1)
        
adj_shooting_df.head()
# Out:
#   adj_efg_pct adj_fg2_pct adj_fg3_pct adj_fg3a_rate adj_fg_pct adj_ft_pct  \
# 0         103         106          99           145         96        112
# 1          93          98          72            43        102         99
# 2         115         125         112           216         97         97
# 3         103         105         102           171         93        105
# 4          98          95          99           140         92         91
#
#   adj_ft_rate adj_ts_pct age efg_pct  ... fg_pts_added ft_pct ft_rate   g  \
# 0         203        111  30    .543  ...         41.7   .865    .528  68
# 1         114         95  31    .493  ...        -91.9   .763    .297  57
# 2          47        110  26    .610  ...         88.6   .746    .123  71
# 3          64        101  26    .546  ...         18.9   .811    .167  63
# 4          85         96  27    .517  ...        -11.9   .703    .222  68
#
#                         link    mp             player rank ts_pct ts_pts_added
# 0  /players/h/hardeja01.html  2483       James Harden    1   .626        227.5
# 1  /players/w/westbru01.html  2049  Russell Westbrook    2   .536        -82.6
# 2  /players/m/mclembe01.html  1619       Ben McLemore    3   .622         66.2
# 3  /players/h/houseda01.html  1913       Danuel House    4   .572          8.5
# 4  /players/r/riverau01.html  1594      Austin Rivers    5   .542        -25.0
#
# [5 rows x 24 columns]

# %%
##################################################################################################
# All Shooting Table
##################################################################################################

all_shooting_df = pd.DataFrame()

all_shooting_table = soup.find('div', attrs={'id': 'all_shooting'})

all_shooting_info = BeautifulSoup(all_shooting_table.contents[5], 'lxml')

all_shooting_data = all_shooting_info.find('tbody')

for tr in all_shooting_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    all_shooting_dict = {}
    
    all_shooting_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            all_shooting_dict['link'] = td.contents[0]['href'] 
        
        all_shooting_dict[td['data-stat']] = td.text

    all_shooting_df = all_shooting_df.append(all_shooting_dict, ignore_index=True)

    
names = all_shooting_df.columns

for n in names:
    dummy = re.match('DUMMY[\d]?[\s]?', n)
    if dummy:
        all_shooting_df = all_shooting_df.drop(dummy.group(), axis=1)
        
all_shooting_df.head()
# Out:
#   age avg_dist fg3_heave fg3a_heave fg_dunk fg_pct fg_pct_00_03 fg_pct_03_10  \
# 0  30     16.6         0          1      20   .444         .668         .414
# 1  34     18.4         0          0       0   .415         .619         .474
# 2  31     10.1         0          0      40   .472         .640         .363
# 3  26     17.6         0          2      31   .427         .679         .200
# 4  26     21.5         0          2      20   .444         .743         .235
#
#   fg_pct_10_16 fg_pct_16_xx  ... pct_fg3a_corner3 pct_fga_00_03 pct_fga_03_10  \
# 0         .444         .500  ...             .045          .243          .177
# 1         .467         .545  ...             .766          .148          .089
# 2         .404         .402  ...             .192          .415          .142
# 3         .308         .200  ...             .414          .243          .065
# 4        1.000               ...             .294          .136          .031
#
#   pct_fga_10_16 pct_fga_16_xx pct_fga_dunk pct_fga_fg2a pct_fga_fg3a  \
# 0          .018          .005         .015         .443         .557
# 1          .035          .026         .000         .298         .702
# 2          .130          .148         .041         .834         .166
# 3          .024          .009         .072         .341         .659
# 4          .004          .000         .040         .171         .829
#
#               player rank
# 0       James Harden    1
# 1        P.J. Tucker    2
# 2  Russell Westbrook    3
# 3       Danuel House    4
# 4       Ben McLemore    5
#
# [5 rows x 28 columns]

# %%
##################################################################################################
# Play-by-Play Table
##################################################################################################

all_pbp_df = pd.DataFrame()

all_pbp_table = soup.find('div', attrs={'id': 'all_pbp'})

all_pbp_info = BeautifulSoup(all_pbp_table.contents[5], 'lxml')

all_pbp_data = all_pbp_info.find('tbody')

for tr in all_pbp_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    all_pbp_dict = {}
    
    all_pbp_dict['rank'] = rnk.text

    for td in tr.find_all('td'):
        
        if td['data-stat'] == 'player':
            all_pbp_dict['link'] = td.contents[0]['href'] 
        
        all_pbp_dict[td['data-stat']] = td.text

    all_pbp_df = all_pbp_df.append(all_pbp_dict, ignore_index=True)

    
names = all_pbp_df.columns

for n in names:
    dummy = re.match('DUMMY[\d]?[\s]?', n)
    if dummy:
        all_pbp_df = all_pbp_df.drop(dummy.group(), axis=1)
        
all_pbp_df.head()
# Out:
#   age and1s astd_pts drawn_offensive drawn_shooting fouls_offensive  \
# 0  30    75     1226              12            326              51
# 1  34     2      286              42             11              15
# 2  31    46     1014               5            187              25
# 3  26     8      210              21             41               6
# 4  26     3      155               8             26               9
#
#   fouls_shooting   g                       link    mp  ... pct_2 pct_3 pct_4  \
# 0             80  68  /players/h/hardeja01.html  2483  ...   43%   52%    4%
# 1            121  72  /players/t/tuckepj01.html  2467  ...          3%   71%
# 2             68  57  /players/w/westbru01.html  2049  ...
# 3             68  63  /players/h/houseda01.html  1913  ...    1%   63%   36%
# 4             79  71  /players/m/mclembe01.html  1619  ...   52%    1%
#
#   pct_5             player plus_minus_net plus_minus_on rank tov_bad_pass  \
# 0             James Harden           +9.1          +5.6    1          145
# 1   26%        P.J. Tucker           +1.0          +3.3    2           35
# 2        Russell Westbrook           -0.5          +2.8    3          131
# 3    1%       Danuel House           +0.5          +3.2    4           28
# 4             Ben McLemore           +4.4          +5.3    5           22
#
#   tov_lost_ball
# 0            95
# 1             9
# 2            80
# 3            10
# 4            10
#
# [5 rows x 22 columns]

# %%
##################################################################################################
# Play-by-Play Table
##################################################################################################

all_pbp_df = pd.DataFrame()

all_pbp_table = soup.find('div', attrs={'id': 'all_pbp'})

all_pbp_info = BeautifulSoup(all_pbp_table.contents[5], 'lxml')

df_index = []

all_pbp_head = all_pbp_info.find('thead')

for tr in all_pbp_head.find_all('tr'):
    try:
        if tr['class'][0]=='over_header':
            pass
    except:

        for th in tr.find_all('th'):
            if th['data-stat'] == 'ranker' or th['data-over-header'] == ' ':
                df_index.append(('Player', th.text))
            else:
                if th['data-over-header'] == '\xa0':
                    df_index.append(('Player', th.text))
                else:
                    df_index.append((th['data-over-header'], th.text))

all_pbp_df = pd.DataFrame(columns=df_index)                    
all_pbp_df.columns = pd.MultiIndex.from_tuples(all_pbp_df.columns, names=['Header', 'Stat'])


all_pbp_data = all_pbp_info.find('tbody')

for tr in all_pbp_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    all_pbp_list = []
    
    all_pbp_list.append(rnk.text)

    for td in tr.find_all('td'):
        
        all_pbp_list.append(td.text)
        
    all_pbp_df.loc[len(all_pbp_df)] = all_pbp_list

all_pbp_df
# Out:
# Header Player                                   Position Estimate            \
# Stat       Rk              Player Age   G    MP               PG%  SG%  SF%
# 0           1        James Harden  30  68  2483                1%  43%  52%
# 1           2         P.J. Tucker  34  72  2467                          3%
# 2           3   Russell Westbrook  31  57  2049              100%
# 3           4        Danuel House  26  63  1913                     1%  63%
# 4           5        Ben McLemore  26  71  1619               47%  52%   1%
# 5           6       Austin Rivers  27  68  1594               18%  59%  22%
# 6           7        Clint Capela  25  39  1279
# 7           8         Eric Gordon  31  36  1016               11%  48%  34%
# 8           9    Robert Covington  29  22   726
# 9          10     Thabo Sefolosha  35  41   436                          5%
# 10         11          Jeff Green  33  18   407
# 11         12       Chris Clemons  22  33   291               82%  18%
# 12         13  Isaiah Hartenstein  21  23   266
# 13         14      Tyson Chandler  37  26   219
# 14         15          Gary Clark  25  18   212                          4%
# 15         16     DeMarre Carroll  33   9   155                     2%  49%
# 16         17     Michael Frazier  25  13   145                4%  46%  47%
# 17         18       Bruno Caboclo  24   8    52
# 18         19    Luc Mbah a Moute  33   3    25
# 19         20       Ryan Anderson  31   2    14
# 20         21      William Howard  26   2    13
#
# Header              ... +/- Per 100 Poss. Turnovers          Fouls Committed  \
# Stat     PF%    C%  ...            On-Off   BadPass LostBall           Shoot
# 0         4%        ...              +9.1       145       95              80
# 1        71%   26%  ...              +1.0        35        9             121
# 2                   ...              -0.5       131       80              68
# 3        36%    1%  ...              +0.5        28       10              68
# 4                   ...              +4.4        22       10              79
# 5         1%        ...              -0.7        22       15              71
# 6             100%  ...              -1.0        22       22              35
# 7         6%        ...              -3.8        15       16              35
# 8        28%   72%  ...              +2.8        11        8              40
# 9        79%   16%  ...              +0.4         8        0              21
# 10        4%   96%  ...              -1.8         4        7              23
# 11                  ...             -15.2        11        2              14
# 12            100%  ...              +4.8         7        2              22
# 13            100%  ...              +1.8         1        1              21
# 14       86%   10%  ...              +0.5         1        1              16
# 15       49%        ...              -9.0         2        4               8
# 16        4%        ...             -18.8         4        0              11
# 17            100%  ...             -13.4         4        2               4
# 18      100%        ...             -14.8         1        0               0
# 19            100%  ...             +19.0         1        0               1
# 20      100%        ...             -56.1         0        1               1
#
# Header      Fouls Drawn      Misc.
# Stat   Off.       Shoot Off.   PGA And1 Blkd
# 0        51         326   12  1226   75   92
# 1        15          11   42   286    2   13
# 2        25         187    5  1014   46   81
# 3         6          41   21   210    8   19
# 4         9          26    8   155    3   21
# 5         6          51   18   292   15   27
# 6         9          54   12   122   16   40
# 7         5          50    4   144   15   29
# 8         6          15    5    85    4    9
# 9         1           3    2    66    2    5
# 10        3          11    5    81    2    4
# 11        2           2    6    64    0    4
# 12        3          12    2    43    6    2
# 13        4           6    2    13    1    1
# 14        0           3    0    32    1    1
# 15        0          10    2    39    2    2
# 16        0           3    1     6    0    3
# 17        0           2    0     6    0    1
# 18        0           1    0     0    0    0
# 19        0           0    0     6    0    0
# 20        0           0    0     3    0    0
#
# [21 rows x 21 columns]

# %%
##################################################################################################
# Play-by-Play Table
##################################################################################################

#all_pbp_df = pd.DataFrame()

all_pbp_table = soup.find('div', attrs={'id': 'all_pbp'})

all_pbp_info = BeautifulSoup(all_pbp_table.contents[5], 'lxml')

all_pbp_data = all_pbp_info.find('tbody')

for tr in all_pbp_data.find_all('tr'):
    
    rnk = tr.find('th')
    
    all_pbp_list = []
    
    all_pbp_list.append(rnk.text)

    for td in tr.find_all('td'):
        
        all_pbp_list.append(td.text)
        
    all_pbp_df.loc[len(all_pbp_df)] = all_pbp_list

all_pbp_df
# Out:
# Header Player                                   Position Estimate            \
# Stat       Rk              Player Age   G    MP               PG%  SG%  SF%
# 0           1        James Harden  30  68  2483                1%  43%  52%
# 1           2         P.J. Tucker  34  72  2467                          3%
# 2           3   Russell Westbrook  31  57  2049              100%
# 3           4        Danuel House  26  63  1913                     1%  63%
# 4           5        Ben McLemore  26  71  1619               47%  52%   1%
# 5           6       Austin Rivers  27  68  1594               18%  59%  22%
# 6           7        Clint Capela  25  39  1279
# 7           8         Eric Gordon  31  36  1016               11%  48%  34%
# 8           9    Robert Covington  29  22   726
# 9          10     Thabo Sefolosha  35  41   436                          5%
# 10         11          Jeff Green  33  18   407
# 11         12       Chris Clemons  22  33   291               82%  18%
# 12         13  Isaiah Hartenstein  21  23   266
# 13         14      Tyson Chandler  37  26   219
# 14         15          Gary Clark  25  18   212                          4%
# 15         16     DeMarre Carroll  33   9   155                     2%  49%
# 16         17     Michael Frazier  25  13   145                4%  46%  47%
# 17         18       Bruno Caboclo  24   8    52
# 18         19    Luc Mbah a Moute  33   3    25
# 19         20       Ryan Anderson  31   2    14
# 20         21      William Howard  26   2    13
#
# Header              ... +/- Per 100 Poss. Turnovers          Fouls Committed  \
# Stat     PF%    C%  ...            On-Off   BadPass LostBall           Shoot
# 0         4%        ...              +9.1       145       95              80
# 1        71%   26%  ...              +1.0        35        9             121
# 2                   ...              -0.5       131       80              68
# 3        36%    1%  ...              +0.5        28       10              68
# 4                   ...              +4.4        22       10              79
# 5         1%        ...              -0.7        22       15              71
# 6             100%  ...              -1.0        22       22              35
# 7         6%        ...              -3.8        15       16              35
# 8        28%   72%  ...              +2.8        11        8              40
# 9        79%   16%  ...              +0.4         8        0              21
# 10        4%   96%  ...              -1.8         4        7              23
# 11                  ...             -15.2        11        2              14
# 12            100%  ...              +4.8         7        2              22
# 13            100%  ...              +1.8         1        1              21
# 14       86%   10%  ...              +0.5         1        1              16
# 15       49%        ...              -9.0         2        4               8
# 16        4%        ...             -18.8         4        0              11
# 17            100%  ...             -13.4         4        2               4
# 18      100%        ...             -14.8         1        0               0
# 19            100%  ...             +19.0         1        0               1
# 20      100%        ...             -56.1         0        1               1
#
# Header      Fouls Drawn      Misc.
# Stat   Off.       Shoot Off.   PGA And1 Blkd
# 0        51         326   12  1226   75   92
# 1        15          11   42   286    2   13
# 2        25         187    5  1014   46   81
# 3         6          41   21   210    8   19
# 4         9          26    8   155    3   21
# 5         6          51   18   292   15   27
# 6         9          54   12   122   16   40
# 7         5          50    4   144   15   29
# 8         6          15    5    85    4    9
# 9         1           3    2    66    2    5
# 10        3          11    5    81    2    4
# 11        2           2    6    64    0    4
# 12        3          12    2    43    6    2
# 13        4           6    2    13    1    1
# 14        0           3    0    32    1    1
# 15        0          10    2    39    2    2
# 16        0           3    1     6    0    3
# 17        0           2    0     6    0    1
# 18        0           1    0     0    0    0
# 19        0           0    0     6    0    0
# 20        0           0    0     3    0    0
#
# [21 rows x 21 columns]

# %%
type(all_pbp_df)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
##################################################################################################
# Play-by-Play Table
##################################################################################################

all_pbp_df = pd.DataFrame()

all_pbp_table = soup.find('div', attrs={'id': 'all_pbp'})

all_pbp_info = BeautifulSoup(all_pbp_table.contents[5], 'lxml')

all_pbp_data = all_pbp_info.find('tbody')

all_pbp_head = all_pbp_info.find('thead')

for th in all_pbp_head.find_all('th', attrs={'class': 'over_header'}):
    i = 0
#    try:
#         if th.has_attr('colspan'):
#             print(th.attrs)

    for tr in all_pbp_data.find_all('tr'):

        i += 1

        rnk = tr.find('th')

        all_pbp_dict = {}

        for td in tr.find_all('td'):
            
            all_pbp_dict[('Player', 'rank')] = rnk.text
            
            if i < 8:
                
                if td['data-stat'] == 'player':
                    all_pbp_dict[('Player', 'link')] = td.contents[0]['href'] 
                #print(td)
                all_pbp_dict[('Player', td['data-stat'])] = td.text

            elif i >= 8 & i < 14:
                
                all_pbp_dict[('% of FGA by Distance', td['data-stat'])] = td.text

            elif i >= 14 & i < 20:

                all_pbp_dict[('FG% by Distance', td['data-stat'])] = td.text

            elif i >= 20 & i < 22:

                all_pbp_dict[('% of FG Ast\'d', td['data-stat'])] = td.text

            elif i >= 22 & i < 24:
                
                all_pbp_dict[('Dunks', td['data-stat'])] = td.text

            elif i >= 24 & i < 26:

                all_pbp_dict[('Corner 3s', td['data-stat'])] = td.text

            else:
                all_pbp_dict[('Heaves', td['data-stat'])] = td.text

        all_pbp_df = all_pbp_df.append(all_pbp_dict, ignore_index=True)
#pd.DataFrame(all_pbp_dict, index=['Michael', 'Joey'])
    
# names = all_pbp_df.columns

# for n in names:
#     dummy = re.match('DUMMY[\d]?[\s]?', n)
#     if dummy:
#         all_pbp_df = all_pbp_df.drop(dummy.group(), axis=1)
        
# all_pbp_df.head()

# %%
all_pbp_df
# Out:
#     (Player, rank)             (Player, link)   (Player, player)  \
# 0                1  /players/h/hardeja01.html       James Harden
# 1                2  /players/t/tuckepj01.html        P.J. Tucker
# 2                3  /players/w/westbru01.html  Russell Westbrook
# 3                4  /players/h/houseda01.html       Danuel House
# 4                5  /players/m/mclembe01.html       Ben McLemore
# ..             ...                        ...                ...
# 142             17                        NaN                NaN
# 143             18                        NaN                NaN
# 144             19                        NaN                NaN
# 145             20                        NaN                NaN
# 146             21                        NaN                NaN
#
#     (Player, age) (Player, g) (Player, mp) (Player, pct_1) (Player, pct_2)  \
# 0              30          68         2483              1%             43%
# 1              34          72         2467
# 2              31          57         2049            100%
# 3              26          63         1913                              1%
# 4              26          71         1619             47%             52%
# ..            ...         ...          ...             ...             ...
# 142           NaN         NaN          NaN             NaN             NaN
# 143           NaN         NaN          NaN             NaN             NaN
# 144           NaN         NaN          NaN             NaN             NaN
# 145           NaN         NaN          NaN             NaN             NaN
# 146           NaN         NaN          NaN             NaN             NaN
#
#     (Player, pct_3) (Player, pct_4)  ... (% of FGA by Distance, pct_1)  \
# 0               52%              4%  ...                           NaN
# 1                3%             71%  ...                           NaN
# 2                                    ...                           NaN
# 3               63%             36%  ...                           NaN
# 4                1%                  ...                           NaN
# ..              ...             ...  ...                           ...
# 142             NaN             NaN  ...                            4%
# 143             NaN             NaN  ...
# 144             NaN             NaN  ...
# 145             NaN             NaN  ...
# 146             NaN             NaN  ...
#
#     (% of FGA by Distance, pct_2) (% of FGA by Distance, pct_3)  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ..                            ...                           ...
# 142                           46%                           47%
# 143
# 144
# 145
# 146
#
#     (% of FGA by Distance, pct_4) (% of FGA by Distance, pct_5)  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ..                            ...                           ...
# 142                            4%
# 143                                                        100%
# 144                          100%
# 145                                                        100%
# 146                          100%
#
#     (% of FGA by Distance, player) (% of FGA by Distance, plus_minus_net)  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
# ..                             ...                                    ...
# 142                Michael Frazier                                  -18.8
# 143                  Bruno Caboclo                                  -13.4
# 144               Luc Mbah a Moute                                  -14.8
# 145                  Ryan Anderson                                  +19.0
# 146                 William Howard                                  -56.1
#
#     (% of FGA by Distance, plus_minus_on)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 142                                 -15.1
# 143                                 -10.2
# 144                                 -11.7
# 145                                 +21.9
# 146                                 -53.0
#
#     (% of FGA by Distance, tov_bad_pass) (% of FGA by Distance, tov_lost_ball)
# 0                                    NaN                                   NaN
# 1                                    NaN                                   NaN
# 2                                    NaN                                   NaN
# 3                                    NaN                                   NaN
# 4                                    NaN                                   NaN
# ..                                   ...                                   ...
# 142                                    4                                     0
# 143                                    4                                     2
# 144                                    1                                     0
# 145                                    1                                     0
# 146                                    0                                     1
#
# [147 rows x 42 columns]

# %%
##################################################################################################
# Play-by-Play Table
##################################################################################################

all_pbp_df = pd.DataFrame()

all_pbp_table = soup.find('div', attrs={'id': 'all_pbp'})

all_pbp_info = BeautifulSoup(all_pbp_table.contents[5], 'lxml')

all_pbp_data = all_pbp_info.find('tbody')

all_pbp_head = all_pbp_info.find('thead')

for tr in all_pbp_head.find_all('tr', attrs={'class': 'over_header'}):
    for th in tr.find_all('th'):
        print(th.text)
        
        fo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e89aecca6cd2> in <module>
#      17         print(th.text)
#      18
# ---> 19         fo
#      20
#
# NameError: name 'fo' is not defined

# %%
dic =  {('candy', 'popsicle'): ['chocolate', 'purple'], ('candy', 'cake'): ['vanilla', 'pink'], ('healthy', 'fruit'): ['carrot', 'orange'], ('healthy', 'veggie'): ['peas', 'green']}
#dic = pd.Series(dic).reset_index()
# pd.DataFrame.from_dict(dic, orient='column')
pd.DataFrame(dic)
# Out:
#        candy          healthy
#     popsicle     cake   fruit veggie
# 0  chocolate  vanilla  carrot   peas
# 1     purple     pink  orange  green

# %%
index = [np.array(['Player'] * 5, ['Position Estimate'] * 5, ['+/- Per 100 Poss.'] * 2, ''),]
index
# Out:
# [array(['Player', 'Player', 'Player', 'Player', 'Player'], dtype='<U6')]

# %%
all_pbp_df.columns = pd.MultiIndex().to_frame()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-257-9317cb99c907> in <module>
# ----> 1 all_pbp_df.columns = pd.MultiIndex().to_frame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in __new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity, _set_identity)
#     255             names = name
#     256         if levels is None or codes is None:
# --> 257             raise TypeError("Must pass both levels and codes")
#     258         if len(levels) != len(codes):
#     259             raise ValueError("Length of levels and codes must be the same.")
#
# TypeError: Must pass both levels and codes

# %%
dictionary = {'A' : {'a': [1,2,3,4,5],
                     'b': [6,7,8,9,1]},

              'B' : {'a': [2,3,4,5,6],
                     'b': [7,8,9,1,2]}}
reform = {(outerKey, innerKey): values for outerKey, innerDict in dictionary.iteritems() for innerKey, values in innerDict.iteritems()}
reform
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-278-c5a87fadbb3d> in <module>
#       4               'B' : {'a': [2,3,4,5,6],
#       5                      'b': [7,8,9,1,2]}}
# ----> 6 reform = {(outerKey, innerKey): values for outerKey, innerDict in dictionary.iteritems() for innerKey, values in innerDict.iteritems()}
#       7 reform
#
# AttributeError: 'dict' object has no attribute 'iteritems'
